# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.__version__
# Out:
# '0.11.0'

# %%
#need internet
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
tips=sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_style('darkgrid',{'axes.grid':True})
sns.lmplot(x='total_bill',y='tip',data=tips)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='Dark2')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## UNIVALIATE (one variable)

# %%
#strip plot
sns.stripplot(y='tip',data=tips,jitter=True)
plt.ylabel('tip($)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#grouping with stripplot
sns.stripplot(x='day',y='tip',data=tips)
plt.ylabel('tip($)')
plt.show()

# %%
sns.stripplot(x='day',y='tip',data=tips,jitter=False)
plt.show()

# %%
#swarm plot
#More denser
sns.swarmplot(x='day',y='tip',data=tips)
plt.show()
# Out:
# C:\Users\satish\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\satish\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='day',y='tip',data=tips,hue='sex')
plt.show
# Out:
# C:\Users\satish\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\satish\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#changing orientation
sns.swarmplot(x='tip',y='day',data=tips,hue='sex',orient='h')
plt.show
# Out:
# C:\Users\satish\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\satish\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 11.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\satish\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Box and violin plot

# %%
plt.subplot(1,2,1)
sns.boxplot(x='day',y='tip',data=tips)
plt.ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')

# %%
plt.subplot(1,2,2)
sns.boxplot(x='day',y='tip',data=tips)
plt.ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')

# %%
plt.subplot(1,2,1)
sns.boxplot(x='day',y='tip',data=tips)
plt.ylabel('tip')
plt.subplot(1,2,2)
sns.boxplot(x='day',y='tip',data=tips)
plt.ylabel('tip')
plt.show()

# %%
#combining plot
sns.violinplot(x='day',y='tip',data=tips,inner=None,color='lightgrey')
sns.stripplot(x='day',y='tip',data=tips,size=4,jitter=True)
plt.show()

# %% [markdown]
# ## Bivariate(Two variable)

# %%
#joint plot
#it uses 2 graphs(scattered and histogram)
sns.jointplot(x='total_bill',y='tip',data=tips)
plt.show()

# %%
#density plot
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')
plt.show()

# %%
#Pair plot
sns.pairplot(tips)
plt.show()

# %%
sns.pairplot(tips,hue='sex')
plt.show()

# %%
#corelation
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#covariance heat map
sns.heatmap(tips.corr(),vmin=-1,vmax=1,cmap='ocean')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Titanic data visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv('Garbage1.csv')

# %%
print(data.dtypes)
# Out:
# binno            int64
# region           int64
# lat            float64
# long           float64
# percentage       int64
# status           int64
# clean _time      int64
# full_time        int64
# dtype: object

# %%
f,ax=plt.subplots(figsize=(11,5))
sns.boxplot(x='binno',y='full_time',data=data)
# Out:
# <AxesSubplot:xlabel='binno', ylabel='full_time'>

# %%
f,ax=plt.subplots(figsize=(7,3))
sns.barplot(x='binno',y='full_time',data=data)
# Out:
# <AxesSubplot:xlabel='binno', ylabel='full_time'>

# %%
f,ax=plt.subplots(figsize=(11,5))
sns.boxplot(x='binno',y='full_time',hue='lat',data=data)
# Out:
# <AxesSubplot:xlabel='binno', ylabel='full_time'>

# %%
sns.barplot(x='binno',y='full_time',data=data)
# Out:
# <AxesSubplot:xlabel='binno', ylabel='full_time'>

# %%
su=data.loc[data['full_time']==1,'lat'].dropna()
sns.distplot(su)
# Out:
# <AxesSubplot:xlabel='lat'>

# %%
sns.pairplot(data.dropna())

# %%
grid=sns.FacetGrid(data,col='binno',row='lat',size=2.6,aspect=1.6)
grid.map(plt.hist,'full_time',alpha=.5,bins=20)
grid.add_legend()
